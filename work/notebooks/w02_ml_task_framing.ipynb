# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Scoring (with ranking as the final output). It fits Lane 2 because the goal is to assign each page a refresh-opportunity score and prioritize pages for review based on that score.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I would predict whether a page is declining (trend_direction = down). The label comes from a defined rule, since trend_direction is a precomputed field derived from observed performance trends rather than a directly observed future outcome

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# **Precision@50.** A good model should place genuinely high-priority refresh candidates near the top of the queue, so a higher Precision@50 means more of the top 50 recommended pages truly need review.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
df=pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
dfnew=df[df['impressions_90d']> 0]
dfnew=df[df['content_age_days']>=90]

dfnew.describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %%
dfnew[['content_id']].head()
# Out:
#              content_id
# 0  content_304f48230142
# 1  content_a1fb4e703a9e
# 2  content_9aa793d4d895
# 3  content_331d6c4de07b
# 4  content_d99b7a2d90ca

# %% [markdown]
# *One row = one content page (content_id) with its associated search, engagement, freshness, and performance metrics over the observation window.*

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# *A fixed rule cannot capture the complex interactions between traffic, engagement, rankings, content age, freshness, and content characteristics. An ML model can learn these relationships simultaneously and produce a more accurate refresh-priority score than a simple threshold-based rule.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
